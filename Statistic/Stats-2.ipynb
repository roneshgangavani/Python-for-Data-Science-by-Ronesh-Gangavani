# %%
from scipy import stats
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
bp =[ 125,130,135,120,120,122,115,105,115,135,125,125]
print("Skewness:",stats.skew(bp))
print("Kurtosis:",stats.kurtosis(bp))
sb.distplot(bp);
# Out:
# Skewness: -0.33553914203133656
# Kurtosis: -0.24838990334114808

# %% [markdown]
# ### Assignment
# Generate BP data which is highly neg skewed, S < -1
